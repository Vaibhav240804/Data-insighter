# %% [markdown]
# # Python Extract Table from PDF

# %% [markdown]
# Example PDFs
#
# * McKinsey Global Institute Disruptive technologies
#
# https://www.mckinsey.com/~/media/McKinsey/Business%20Functions/McKinsey%20Digital/Our%20Insights/Disruptive%20technologies/MGI_Disruptive_technologies_Full_report_May2013.ashx
#
# * Food Calories List
#
# http://www.uncledavesenterprise.com/file/health/Food%20Calories%20List.pdf

# %% [markdown]
# ## With tabula-py
#
# #### Installation
#
# https://pypi.org/project/tabula-py/
#
# `pip install tabula-py`
#
# #### tabula-py docs
#
# https://www.pydoc.io/pypi/tabula-py-0.9.0/autoapi/wrapper/index.html

# %%
from tabula import read_pdf
from tabulate import tabulate

# %%
df = read_pdf("mse.pdf")
print(type(df))
df
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# <class 'list'>
# [    Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4  \
#  0          1.0  4th March        10-11       Extc         SE
#  1          NaN       2024          NaN        NaN        NaN
#  2          NaN        NaN          NaN        CSE         SE
#  3          NaN        NaN          NaN         CE         SE
#  4          NaN        NaN          NaN      FYMCA         FY
#  5          NaN        NaN          NaN       EXTC         SE
#  6          NaN        NaN          NaN        CSE         SE
#  7          NaN        NaN          NaN         CE         SE
#  8          NaN        NaN  11.30-12.30       Extc         TE
#  9          NaN        NaN          NaN     CSE-DS         TE
#  10         NaN        NaN          NaN   CSE-AIML         TE
#  11         NaN        NaN          NaN         CE         TE
#  12         NaN        NaN          NaN        NaN        NaN
#  13         NaN        NaN          2-3       Extc         TE
#  14         NaN        NaN          NaN       Etrx         BE
#  15         NaN        NaN          NaN     CSE-DS         TE
#  16         NaN        NaN          NaN    IT/COMP         BE
#  17         NaN        NaN          NaN   CSE-AIML         TE
#  18         NaN        NaN          NaN         CE         TE
#  19         NaN        NaN          NaN     M.tech       extc
#  20         NaN        NaN          NaN     M.Tech       Comp
#  21         NaN        NaN          NaN        NaN        NaN
#  22         NaN        NaN          NaN     FE All         FE
#
#                          Course Name
#  0        Probability and Stochastic
#  1                         Processes
#  2                    Linear Algebra
#  3                    Linear Algebra
#  4               Prob and statistics
#  5                   FM1I (only DSE)
#  6                   FM1I (only DSE)
#  7                  FM II (only DSE)
#  8                            PE/FOA
#  9             Distributed Computing
#  10            Distributed Computing
#  11  System Programming and Compiler
#  12                     Construction
#  13                      RTES/ITC/WT
#  14                      RTES/ITC/WT
#  15                              NaN
#  16                               ML
#  17                              NaN
#  18                               ML
#  19        Advanced Radiating System
#  20             Advanced Network and
#  21             Communication System
#  22                         Maths-II  ]

# %%
df = read_pdf("mse.pdf")
df = df.dropna(axis='columns')
df
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# c:\Python312\Lib\site-packages\tabula\io.py:1045: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[c] = pd.to_numeric(df[c], errors="ignore")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 df = read_pdf("mse.pdf")
#       2 # convert PDF into CSV
# ----> 3 df.to_csv("mse.csv", index=False)
#       4 df = df.dropna(axis='columns')
#       5 df
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
df = read_pdf("mse.pdf", pages=3)
print(tabulate(df))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3992\2425755100.py in ?()
#       1 df = read_pdf("mse.pdf", pages=3)
# ----> 2 print(tabulate(df))
#
# c:\Python312\Lib\site-packages\tabulate\__init__.py in ?(tabular_data, headers, tablefmt, floatfmt, intfmt, numalign, stralign, missingval, showindex, disable_numparse, colalign, maxcolwidths, rowalign, maxheadercolwidths)
#    2044
#    2045     if tabular_data is None:
#    2046         tabular_data = []
#    2047
# -> 2048     list_of_lists, headers = _normalize_tabular_data(
#    2049         tabular_data, headers, showindex=showindex
#    2050     )
#    2051     list_of_lists, separating_lines = _remove_separating_lines(list_of_lists)
#
# c:\Python312\Lib\site-packages\tabulate\__init__.py in ?(tabular_data, headers, showindex)
#    1467         headers = []
#    1468
#    1469     headers = list(map(str, headers))
#    1470     #    rows = list(map(list, rows))
# -> 1471     rows = list(map(lambda r: r if _is_separating_line(r) else list(r), rows))
#    1472
#    1473     # add or remove an index column
#    1474     showindex_is_a_str = type(showindex) in [str, bytes]
#
# c:\Python312\Lib\site-packages\tabulate\__init__.py in ?(r)
# -> 1471     rows = list(map(lambda r: r if _is_separating_line(r) else list(r), rows))
#
# c:\Python312\Lib\site-packages\tabulate\__init__.py in ?(row)
#     104 def _is_separating_line(row):
#     105     row_type = type(row)
#     106     is_sl = (row_type == list or row_type == str) and (
# --> 107         (len(row) >= 1 and row[0] == SEPARATING_LINE)
#     108         or (len(row) >= 2 and row[1] == SEPARATING_LINE)
#     109     )
#     110     return is_sl
#
# c:\Python312\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1574     @final
#    1575     def __nonzero__(self) -> NoReturn:
# -> 1576         raise ValueError(
#    1577             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1578             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1579         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df = read_pdf("mse.pdf", pages=3, output_format="json")
df
# Out:
# [{'extraction_method': 'stream',
#   'top': 72.0,
#   'left': 72.0,
#   'width': 504.0,
#   'height': 733.0,
#   'right': 576.0,
#   'bottom': 805.0,
#   'data': [[{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 82.17,
#      'left': 181.5,
#      'width': 17.816741943359375,
#      'height': 6.139999866485596,
#      'text': '2-3'},
#     {'top': 82.17,
#      'left': 256.5,
#      'width': 23.154022216796875,
#      'height': 6.139999866485596,
#      'text': 'Extc'},
#     {'top': 82.17,
#      'left': 332.25,
#      'width': 16.2860107421875,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 82.17,
#      'left': 390.0,
#      'width': 46.39999008178711,
#      'height': 6.139999866485596,
#      'text': 'HMI (OE)'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 106.07,
#      'left': 256.5,
#      'width': 43.59918212890625,
#      'height': 6.139999866485596,
#      'text': 'CSE-DS'},
#     {'top': 106.07,
#      'left': 332.25,
#      'width': 16.4013671875,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 106.07,
#      'left': 390.0,
#      'width': 45.189998626708984,
#      'height': 6.139999866485596,
#      'text': 'HMI (PE)'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 129.97,
#      'left': 256.5,
#      'width': 53.907318115234375,
#      'height': 6.139999866485596,
#      'text': 'CSE-AIML'},
#     {'top': 129.97,
#      'left': 332.25,
#      'width': 16.34393310546875,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 129.97,
#      'left': 390.0,
#      'width': 45.189998626708984,
#      'height': 6.139999866485596,
#      'text': 'HMI (PE)'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 153.87,
#      'left': 256.5,
#      'width': 17.3299560546875,
#      'height': 6.139999866485596,
#      'text': 'CE'},
#     {'top': 153.87,
#      'left': 332.25,
#      'width': 16.39984130859375,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 153.87,
#      'left': 390.0,
#      'width': 45.189998626708984,
#      'height': 6.139999866485596,
#      'text': 'HMI (PE)'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 177.77,
#      'left': 256.5,
#      'width': 48.079681396484375,
#      'height': 6.139999866485596,
#      'text': 'IT/COMP'},
#     {'top': 177.77,
#      'left': 332.25,
#      'width': 17.0555419921875,
#      'height': 6.139999866485596,
#      'text': 'BE'},
#     {'top': 177.77,
#      'left': 390.0,
#      'width': 45.189998626708984,
#      'height': 6.139999866485596,
#      'text': 'HMI (PE)'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 201.67,
#      'left': 256.5,
#      'width': 37.248931884765625,
#      'height': 6.139999866485596,
#      'text': 'M.Tech'},
#     {'top': 201.67,
#      'left': 332.25,
#      'width': 22.022247314453125,
#      'height': 6.139999866485596,
#      'text': 'extc'},
#     {'top': 201.67,
#      'left': 390.0,
#      'width': 93.47000122070312,
#      'height': 6.139999866485596,
#      'text': 'Program Elective-II'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 225.57,
#      'left': 256.5,
#      'width': 37.151824951171875,
#      'height': 6.139999866485596,
#      'text': 'M.Tech'},
#     {'top': 225.57,
#      'left': 332.25,
#      'width': 29.03515625,
#      'height': 6.139999866485596,
#      'text': 'comp'},
#     {'top': 225.57,
#      'left': 390.0,
#      'width': 93.47000122070312,
#      'height': 6.139999866485596,
#      'text': 'Program Elective-II'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 249.47,
#      'left': 181.5,
#      'width': 48.407501220703125,
#      'height': 6.139999866485596,
#      'text': '3.30-4.30'},
#     {'top': 249.47,
#      'left': 256.5,
#      'width': 21.53948974609375,
#      'height': 6.139999866485596,
#      'text': 'ALL'},
#     {'top': 249.47,
#      'left': 332.25,
#      'width': 16.25103759765625,
#      'height': 6.139999866485596,
#      'text': 'FE'},
#     {'top': 249.47,
#      'left': 390.0,
#      'width': 60.489994049072266,
#      'height': 6.139999866485596,
#      'text': 'ELECTIVES'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 262.11,
#      'left': 256.5,
#      'width': 52.54001235961914,
#      'height': 6.139999866485596,
#      'text': 'DIVISONS'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 286.01,
#      'left': 77.25,
#      'width': 8.057746887207031,
#      'height': 6.139999866485596,
#      'text': '4'},
#     {'top': 286.01,
#      'left': 108.0,
#      'width': 50.66302490234375,
#      'height': 6.139999866485596,
#      'text': '7th March'},
#     {'top': 286.01,
#      'left': 181.5,
#      'width': 29.2803955078125,
#      'height': 6.139999866485596,
#      'text': '10-11'},
#     {'top': 286.01,
#      'left': 256.5,
#      'width': 23.24920654296875,
#      'height': 6.139999866485596,
#      'text': 'Extc'},
#     {'top': 286.01,
#      'left': 332.25,
#      'width': 14.669986724853516,
#      'height': 6.139999866485596,
#      'text': 'SE'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 298.66,
#      'left': 108.0,
#      'width': 26.487899780273438,
#      'height': 6.139999866485596,
#      'text': '2024'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 298.66,
#      'left': 390.0,
#      'width': 102.64999389648438,
#      'height': 6.139999866485596,
#      'text': 'Signals and Systems'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 322.56,
#      'left': 256.5,
#      'width': 24.8050537109375,
#      'height': 6.139999866485596,
#      'text': 'CSE'},
#     {'top': 322.56,
#      'left': 332.25,
#      'width': 17.043426513671875,
#      'height': 6.139999866485596,
#      'text': 'SE'},
#     {'top': 322.56,
#      'left': 390.0,
#      'width': 154.58001708984375,
#      'height': 6.139999866485596,
#      'text': 'Computer Communications and'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 335.21,
#      'left': 390.0,
#      'width': 45.80999755859375,
#      'height': 6.139999866485596,
#      'text': 'Networks'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 359.11,
#      'left': 256.5,
#      'width': 17.430389404296875,
#      'height': 6.139999866485596,
#      'text': 'CE'},
#     {'top': 359.11,
#      'left': 332.25,
#      'width': 17.036163330078125,
#      'height': 6.139999866485596,
#      'text': 'SE'},
#     {'top': 359.11,
#      'left': 390.0,
#      'width': 154.58001708984375,
#      'height': 6.139999866485596,
#      'text': 'Computer Communications and'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 371.76,
#      'left': 390.0,
#      'width': 45.80999755859375,
#      'height': 6.139999866485596,
#      'text': 'Networks'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 395.66,
#      'left': 256.5,
#      'width': 40.633453369140625,
#      'height': 6.139999866485596,
#      'text': 'FYMCA'},
#     {'top': 395.66,
#      'left': 332.25,
#      'width': 16.32666015625,
#      'height': 6.139999866485596,
#      'text': 'FY'},
#     {'top': 395.66,
#      'left': 390.0,
#      'width': 98.37000274658203,
#      'height': 6.139999866485596,
#      'text': 'Process Automation'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 419.56,
#      'left': 181.5,
#      'width': 59.824920654296875,
#      'height': 6.139999866485596,
#      'text': '11.30-12.30'},
#     {'top': 419.56,
#      'left': 256.5,
#      'width': 23.155181884765625,
#      'height': 6.139999866485596,
#      'text': 'Extc'},
#     {'top': 419.56,
#      'left': 332.25,
#      'width': 16.196197509765625,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 419.56,
#      'left': 390.0,
#      'width': 65.97000122070312,
#      'height': 6.139999866485596,
#      'text': 'SAP/DCMOS'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 443.46,
#      'left': 256.5,
#      'width': 54.10272216796875,
#      'height': 6.139999866485596,
#      'text': 'Etrx/EXTC'},
#     {'top': 443.46,
#      'left': 332.25,
#      'width': 16.975555419921875,
#      'height': 6.139999866485596,
#      'text': 'BE'},
#     {'top': 443.46,
#      'left': 390.0,
#      'width': 65.97000122070312,
#      'height': 6.139999866485596,
#      'text': 'SAP/DCMOS'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 467.35,
#      'left': 256.5,
#      'width': 43.60516357421875,
#      'height': 6.139999866485596,
#      'text': 'CSE-DS'},
#     {'top': 467.35,
#      'left': 332.25,
#      'width': 16.31231689453125,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 467.35,
#      'left': 390.0,
#      'width': 94.66000366210938,
#      'height': 6.139999866485596,
#      'text': 'BA WITH PYTHON'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 491.25,
#      'left': 256.5,
#      'width': 48.0830078125,
#      'height': 6.139999866485596,
#      'text': 'IT/COMP'},
#     {'top': 491.25,
#      'left': 332.25,
#      'width': 16.966094970703125,
#      'height': 6.139999866485596,
#      'text': 'BE'},
#     {'top': 491.25,
#      'left': 390.0,
#      'width': 94.66000366210938,
#      'height': 6.139999866485596,
#      'text': 'BA WITH PYTHON'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 515.15,
#      'left': 256.5,
#      'width': 53.90899658203125,
#      'height': 6.139999866485596,
#      'text': 'CSE-AIML'},
#     {'top': 515.15,
#      'left': 332.25,
#      'width': 16.25421142578125,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 515.15,
#      'left': 390.0,
#      'width': 94.66000366210938,
#      'height': 6.139999866485596,
#      'text': 'BA WITH PYTHON'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 539.05,
#      'left': 256.5,
#      'width': 17.4371337890625,
#      'height': 6.139999866485596,
#      'text': 'CE'},
#     {'top': 539.05,
#      'left': 332.25,
#      'width': 16.3272705078125,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 539.05,
#      'left': 390.0,
#      'width': 94.66000366210938,
#      'height': 6.139999866485596,
#      'text': 'BA WITH PYTHON'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 562.95,
#      'left': 181.5,
#      'width': 17.852447509765625,
#      'height': 6.139999866485596,
#      'text': '2-3'},
#     {'top': 562.95,
#      'left': 256.5,
#      'width': 23.155487060546875,
#      'height': 6.139999866485596,
#      'text': 'Extc'},
#     {'top': 562.95,
#      'left': 332.25,
#      'width': 16.379241943359375,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 562.95,
#      'left': 390.0,
#      'width': 128.27999877929688,
#      'height': 6.139999866485596,
#      'text': 'OE (except HMI and BCT)'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 586.85,
#      'left': 256.5,
#      'width': 43.59942626953125,
#      'height': 6.139999866485596,
#      'text': 'CSE-DS'},
#     {'top': 586.85,
#      'left': 332.25,
#      'width': 16.494384765625,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 586.85,
#      'left': 390.0,
#      'width': 128.27999877929688,
#      'height': 6.139999866485596,
#      'text': 'OE (except HMI and BCT)'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 610.75,
#      'left': 256.5,
#      'width': 53.907470703125,
#      'height': 6.139999866485596,
#      'text': 'CSE-AIML'},
#     {'top': 610.75,
#      'left': 332.25,
#      'width': 16.43695068359375,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 610.75,
#      'left': 390.0,
#      'width': 128.27999877929688,
#      'height': 6.139999866485596,
#      'text': 'OE (except HMI and BCT)'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 634.65,
#      'left': 256.5,
#      'width': 17.339599609375,
#      'height': 6.139999866485596,
#      'text': 'CE'},
#     {'top': 634.65,
#      'left': 332.25,
#      'width': 16.494415283203125,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 634.65,
#      'left': 390.0,
#      'width': 128.27999877929688,
#      'height': 6.139999866485596,
#      'text': 'OE (except HMI and BCT)'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 658.55,
#      'left': 256.5,
#      'width': 37.24951171875,
#      'height': 6.139999866485596,
#      'text': 'M.Tech'},
#     {'top': 658.55,
#      'left': 332.25,
#      'width': 22.02227783203125,
#      'height': 6.139999866485596,
#      'text': 'extc'},
#     {'top': 658.55,
#      'left': 390.0,
#      'width': 96.51998901367188,
#      'height': 6.139999866485596,
#      'text': 'Program Elective-III'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 682.44,
#      'left': 256.5,
#      'width': 37.151397705078125,
#      'height': 6.139999866485596,
#      'text': 'M.Tech'},
#     {'top': 682.44,
#      'left': 332.25,
#      'width': 29.035125732421875,
#      'height': 6.139999866485596,
#      'text': 'comp'},
#     {'top': 682.44,
#      'left': 390.0,
#      'width': 96.51998901367188,
#      'height': 6.139999866485596,
#      'text': 'Program Elective-III'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 706.34,
#      'left': 181.5,
#      'width': 54.84626770019531,
#      'height': 6.139999866485596,
#      'text': '3.30- 5 pm'},
#     {'top': 706.34,
#      'left': 256.5,
#      'width': 32.758056640625,
#      'height': 6.139999866485596,
#      'text': 'ABCD'},
#     {'top': 706.34,
#      'left': 332.25,
#      'width': 16.35968017578125,
#      'height': 6.139999866485596,
#      'text': 'FE'},
#     {'top': 706.34,
#      'left': 390.0,
#      'width': 46.42999267578125,
#      'height': 6.139999866485596,
#      'text': 'Soft skills'}],
#    [{'top': 730.24,
#      'left': 77.25,
#      'width': 10.702064514160156,
#      'height': 6.139999866485596,
#      'text': '5.'},
#     {'top': 730.24,
#      'left': 108.0,
#      'width': 55.961669921875,
#      'height': 6.139999866485596,
#      'text': '11th march'},
#     {'top': 730.24,
#      'left': 181.5,
#      'width': 17.753753662109375,
#      'height': 6.139999866485596,
#      'text': '2-3'},
#     {'top': 730.24,
#      'left': 256.5,
#      'width': 40.64337158203125,
#      'height': 6.139999866485596,
#      'text': 'FYMCA'},
#     {'top': 730.24,
#      'left': 332.25,
#      'width': 16.328277587890625,
#      'height': 6.139999866485596,
#      'text': 'FY'},
#     {'top': 730.24,
#      'left': 390.0,
#      'width': 82.47998809814453,
#      'height': 6.139999866485596,
#      'text': 'Program elective'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 742.89,
#      'left': 108.0,
#      'width': 24.45999526977539,
#      'height': 6.139999866485596,
#      'text': '2024'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 766.79,
#      'left': 256.5,
#      'width': 43.600921630859375,
#      'height': 6.139999866485596,
#      'text': 'CSE-DS'},
#     {'top': 766.79,
#      'left': 332.25,
#      'width': 16.3116455078125,
#      'height': 6.139999866485596,
#      'text': 'TE'},
#     {'top': 766.79,
#      'left': 390.0,
#      'width': 22.609989166259766,
#      'height': 6.139999866485596,
#      'text': 'BDA'}],
#    [{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 790.69,
#      'left': 256.5,
#      'width': 48.082763671875,
#      'height': 6.139999866485596,
#      'text': 'IT/COMP'},
#     {'top': 790.69,
#      'left': 332.25,
#      'width': 16.966064453125,
#      'height': 6.139999866485596,
#      'text': 'BE'},
#     {'top': 790.69,
#      'left': 390.0,
#      'width': 22.609989166259766,
#      'height': 6.139999866485596,
#      'text': 'BDA'}]]}]

# %%
df = read_pdf("mse.pdf", pages='all', multiple_tables=True)
df
# Out:
# [    Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4  \
#  0          1.0  4th March        10-11       Extc         SE
#  1          NaN       2024          NaN        NaN        NaN
#  2          NaN        NaN          NaN        CSE         SE
#  3          NaN        NaN          NaN         CE         SE
#  4          NaN        NaN          NaN      FYMCA         FY
#  5          NaN        NaN          NaN       EXTC         SE
#  6          NaN        NaN          NaN        CSE         SE
#  7          NaN        NaN          NaN         CE         SE
#  8          NaN        NaN  11.30-12.30       Extc         TE
#  9          NaN        NaN          NaN     CSE-DS         TE
#  10         NaN        NaN          NaN   CSE-AIML         TE
#  11         NaN        NaN          NaN         CE         TE
#  12         NaN        NaN          NaN        NaN        NaN
#  13         NaN        NaN          2-3       Extc         TE
#  14         NaN        NaN          NaN       Etrx         BE
#  15         NaN        NaN          NaN     CSE-DS         TE
#  16         NaN        NaN          NaN    IT/COMP         BE
#  17         NaN        NaN          NaN   CSE-AIML         TE
#  18         NaN        NaN          NaN         CE         TE
#  19         NaN        NaN          NaN     M.tech       extc
#  20         NaN        NaN          NaN     M.Tech       Comp
#  21         NaN        NaN          NaN        NaN        NaN
#  22         NaN        NaN          NaN     FE All         FE
#
#                          Course Name
#  0        Probability and Stochastic
#  1                         Processes
#  2                    Linear Algebra
#  3                    Linear Algebra
#  4               Prob and statistics
#  5                   FM1I (only DSE)
#  6                   FM1I (only DSE)
#  7                  FM II (only DSE)
#  8                            PE/FOA
#  9             Distributed Computing
#  10            Distributed Computing
#  11  System Programming and Compiler
#  12                     Construction
#  13                      RTES/ITC/WT
#  14                      RTES/ITC/WT
#  15                              NaN
#  16                               ML
#  17                              NaN
#  18                               ML
#  19        Advanced Radiating System
#  20             Advanced Network and
#  21             Communication System
#  22                         Maths-II  ,
#      Unnamed: 0 Unnamed: 1    3.30-4.30    divisions Unnamed: 2  \
#  0          2.0  5TH March        10-11         EXTC         SE
#  1          NaN       2024          NaN          NaN        NaN
#  2          NaN        NaN          NaN          CSE         SE
#  3          NaN        NaN          NaN           CE         SE
#  4          NaN        NaN          NaN        FYMCA         FY
#  5          NaN        NaN  11.30-12.30         Extc         TE
#  6          NaN        NaN          NaN       CSE-DS         TE
#  7          NaN        NaN          NaN     CSE-AIML         TE
#  8          NaN        NaN          NaN           CE         TE
#  9          NaN        NaN          NaN          NaN        NaN
#  10         NaN        NaN          2-3    Etrx/Extc         BE
#  11         NaN        NaN          NaN       CSE-DS         TE
#  12         NaN        NaN          NaN      IT/COMP         BE
#  13         NaN        NaN          NaN     CSE-AIML         TE
#  14         NaN        NaN          NaN           CE         TE
#  15         NaN        NaN          NaN       M.tech       extc
#  16         NaN        NaN          NaN       M.Tech       Comp
#  17         NaN        NaN          NaN  DIV A B C D         FE
#  18         NaN        NaN    3.30-4.30          NaN        NaN
#  19         NaN        NaN          NaN  Div E F G H         FE
#  20         3.0  6TH March        10-11         Extc         SE
#  21         NaN       2024          NaN          NaN        NaN
#  22         NaN        NaN          NaN          CSE         SE
#  23         NaN        NaN          NaN           CE         SE
#  24         NaN        NaN          NaN        FYMCA         FY
#  25         NaN        NaN  11.30-12.30         Extc         TE
#  26         NaN        NaN          NaN         Etrx         BE
#  27         NaN        NaN          NaN       CSE-DS         TE
#  28         NaN        NaN          NaN      IT/COMP         BE
#  29         NaN        NaN          NaN     CSE-AIML         TE
#  30         NaN        NaN          NaN           CE         TE
#
#                             Unnamed: 3
#  0                     Analog circuits
#  1                                 NaN
#  2   Design and Analysis of Algorithms
#  3   Design and Analysis of Algorithms
#  4                    Java Programming
#  5                                 CCN
#  6                    Machine learning
#  7                    Machine learning
#  8     Fundamental of Signal and Image
#  9                          Processing
#  10                                TNM
#  11                                NLP
#  12                                NLP
#  13                                NaN
#  14                                NLP
#  15      Modern Wireless Communication
#  16      Distributed Computing Systems
#  17                                BEE
#  18                                NaN
#  19                                DSM
#  20                   Microcontrollers
#  21                                NaN
#  22                  Operating Systems
#  23                  Operating Systems
#  24                                DAA
#  25                                OFC
#  26                                OFC
#  27                                 EH
#  28                                 EH
#  29                                 EH
#  30                                 EH  ,
#      Unnamed: 0  Unnamed: 1          2-3       Extc    TE  \
#  0          NaN         NaN          NaN     CSE-DS    TE
#  1          NaN         NaN          NaN   CSE-AIML    TE
#  2          NaN         NaN          NaN         CE    TE
#  3          NaN         NaN          NaN    IT/COMP    BE
#  4          NaN         NaN          NaN     M.Tech  extc
#  5          NaN         NaN          NaN     M.Tech  comp
#  6          NaN         NaN    3.30-4.30        ALL    FE
#  7          NaN         NaN          NaN   DIVISONS   NaN
#  8          4.0   7th March        10-11       Extc    SE
#  9          NaN        2024          NaN        NaN   NaN
#  10         NaN         NaN          NaN        CSE    SE
#  11         NaN         NaN          NaN        NaN   NaN
#  12         NaN         NaN          NaN         CE    SE
#  13         NaN         NaN          NaN        NaN   NaN
#  14         NaN         NaN          NaN      FYMCA    FY
#  15         NaN         NaN  11.30-12.30       Extc    TE
#  16         NaN         NaN          NaN  Etrx/EXTC    BE
#  17         NaN         NaN          NaN     CSE-DS    TE
#  18         NaN         NaN          NaN    IT/COMP    BE
#  19         NaN         NaN          NaN   CSE-AIML    TE
#  20         NaN         NaN          NaN         CE    TE
#  21         NaN         NaN          2-3       Extc    TE
#  22         NaN         NaN          NaN     CSE-DS    TE
#  23         NaN         NaN          NaN   CSE-AIML    TE
#  24         NaN         NaN          NaN         CE    TE
#  25         NaN         NaN          NaN     M.Tech  extc
#  26         NaN         NaN          NaN     M.Tech  comp
#  27         NaN         NaN   3.30- 5 pm       ABCD    FE
#  28         5.0  11th march          2-3      FYMCA    FY
#  29         NaN        2024          NaN        NaN   NaN
#  30         NaN         NaN          NaN     CSE-DS    TE
#  31         NaN         NaN          NaN    IT/COMP    BE
#
#                         HMI (OE)
#  0                      HMI (PE)
#  1                      HMI (PE)
#  2                      HMI (PE)
#  3                      HMI (PE)
#  4           Program Elective-II
#  5           Program Elective-II
#  6                     ELECTIVES
#  7                           NaN
#  8                           NaN
#  9           Signals and Systems
#  10  Computer Communications and
#  11                     Networks
#  12  Computer Communications and
#  13                     Networks
#  14           Process Automation
#  15                    SAP/DCMOS
#  16                    SAP/DCMOS
#  17               BA WITH PYTHON
#  18               BA WITH PYTHON
#  19               BA WITH PYTHON
#  20               BA WITH PYTHON
#  21      OE (except HMI and BCT)
#  22      OE (except HMI and BCT)
#  23      OE (except HMI and BCT)
#  24      OE (except HMI and BCT)
#  25         Program Elective-III
#  26         Program Elective-III
#  27                  Soft skills
#  28             Program elective
#  29                          NaN
#  30                          BDA
#  31                          BDA  ,
#    Unnamed: 0  CSE-AIML      TE                BDA
#  0        NaN        CE      TE                BDA
#  1        3-4     FYMCA  NON-IT  Operating Systems
#  2        NaN      Extc      TE           BCT (OE)
#  3        NaN    CSE-DS      TE                BCT
#  4        NaN  CSE-AIML      TE                BCT
#  5        NaN        CE      TE                BCT]

# %%
df = read_pdf("mse.pdf", pages=3)
df
# Out:
# c:\Python312\Lib\site-packages\tabula\io.py:1045: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[c] = pd.to_numeric(df[c], errors="ignore")
# [    Unnamed: 0  Unnamed: 1          2-3       Extc    TE  \
#  0          NaN         NaN          NaN     CSE-DS    TE
#  1          NaN         NaN          NaN   CSE-AIML    TE
#  2          NaN         NaN          NaN         CE    TE
#  3          NaN         NaN          NaN    IT/COMP    BE
#  4          NaN         NaN          NaN     M.Tech  extc
#  5          NaN         NaN          NaN     M.Tech  comp
#  6          NaN         NaN    3.30-4.30        ALL    FE
#  7          NaN         NaN          NaN   DIVISONS   NaN
#  8          4.0   7th March        10-11       Extc    SE
#  9          NaN        2024          NaN        NaN   NaN
#  10         NaN         NaN          NaN        CSE    SE
#  11         NaN         NaN          NaN        NaN   NaN
#  12         NaN         NaN          NaN         CE    SE
#  13         NaN         NaN          NaN        NaN   NaN
#  14         NaN         NaN          NaN      FYMCA    FY
#  15         NaN         NaN  11.30-12.30       Extc    TE
#  16         NaN         NaN          NaN  Etrx/EXTC    BE
#  17         NaN         NaN          NaN     CSE-DS    TE
#  18         NaN         NaN          NaN    IT/COMP    BE
#  19         NaN         NaN          NaN   CSE-AIML    TE
#  20         NaN         NaN          NaN         CE    TE
#  21         NaN         NaN          2-3       Extc    TE
#  22         NaN         NaN          NaN     CSE-DS    TE
#  23         NaN         NaN          NaN   CSE-AIML    TE
#  24         NaN         NaN          NaN         CE    TE
#  25         NaN         NaN          NaN     M.Tech  extc
#  26         NaN         NaN          NaN     M.Tech  comp
#  27         NaN         NaN   3.30- 5 pm       ABCD    FE
#  28         5.0  11th march          2-3      FYMCA    FY
#  29         NaN        2024          NaN        NaN   NaN
#  30         NaN         NaN          NaN     CSE-DS    TE
#  31         NaN         NaN          NaN    IT/COMP    BE
#
#                         HMI (OE)
#  0                      HMI (PE)
#  1                      HMI (PE)
#  2                      HMI (PE)
#  3                      HMI (PE)
#  4           Program Elective-II
#  5           Program Elective-II
#  6                     ELECTIVES
#  7                           NaN
#  8                           NaN
#  9           Signals and Systems
#  10  Computer Communications and
#  11                     Networks
#  12  Computer Communications and
#  13                     Networks
#  14           Process Automation
#  15                    SAP/DCMOS
#  16                    SAP/DCMOS
#  17               BA WITH PYTHON
#  18               BA WITH PYTHON
#  19               BA WITH PYTHON
#  20               BA WITH PYTHON
#  21      OE (except HMI and BCT)
#  22      OE (except HMI and BCT)
#  23      OE (except HMI and BCT)
#  24      OE (except HMI and BCT)
#  25         Program Elective-III
#  26         Program Elective-III
#  27                  Soft skills
#  28             Program elective
#  29                          NaN
#  30                          BDA
#  31                          BDA  ]

# %%
df = read_pdf("mse.pdf", encoding = 'ISO-8859-1',
         stream=True, pages = 4, guess = False,  pandas_options={'header':None})
df
# Out:
# c:\Python312\Lib\site-packages\tabula\io.py:1045: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[c] = pd.to_numeric(df[c], errors="ignore")
# [     0         1       2                           3
#  0  NaN  CSE-AIML      TE                         BDA
#  1  NaN        CE      TE                         BDA
#  2  3-4     FYMCA  NON-IT           Operating Systems
#  3  NaN      Extc      TE                    BCT (OE)
#  4  NaN    CSE-DS      TE                         BCT
#  5  NaN  CSE-AIML      TE                         BCT
#  6  NaN        CE      TE                         BCT
#  7  NaN       NaN     NaN                        Sd/-
#  8  NaN       NaN     NaN  Controller of Examinations]

# %%
df = read_pdf("mse.pdf", encoding = 'ISO-8859-1',
         stream=True, guess = False)
df

# %%
df = read_pdf("./tmp/pdf/output.pdf", encoding = 'ISO-8859-1',
         stream=True, area=[269.875, 12.75, 790.5, 961], guess = False)
df

# %% [markdown]
# ## With Camelot
#
# #### Installation
#
# https://pypi.org/project/camelot-py/
#
# `pip install camelot-py`
#
# #### Camelot readme
#
# https://github.com/socialcopsdev/camelot

# %%
import camelot
tables = camelot.read_pdf("mse.pdf")
print(tables)
tables[0].df[1:3]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[16], line 2
#       1 import camelot
# ----> 2 tables = camelot.read_pdf("mse.pdf")
#       3 print(tables)
#       4 tables[0].df[1:3]
#
# File c:\Python312\Lib\site-packages\camelot\io.py:113, in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     111 p = PDFHandler(filepath, pages=pages, password=password)
#     112 kwargs = remove_extra(kwargs, flavor=flavor)
# --> 113 tables = p.parse(
#     114     flavor=flavor,
#     115     suppress_stdout=suppress_stdout,
#     116     layout_kwargs=layout_kwargs,
#     117     **kwargs
#     118 )
#     119 return tables
#
# File c:\Python312\Lib\site-packages\camelot\handlers.py:176, in PDFHandler.parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     174     parser = Lattice(**kwargs) if flavor == "lattice" else Stream(**kwargs)
#     175     for p in pages:
# --> 176         t = parser.extract_tables(
#     177             p, suppress_stdout=suppress_stdout, layout_kwargs=layout_kwargs
#     178         )
#     179         tables.extend(t)
#     180 return TableList(sorted(tables))
#
# File c:\Python312\Lib\site-packages\camelot\parsers\lattice.py:421, in Lattice.extract_tables(self, filename, suppress_stdout, layout_kwargs)
#     416         warnings.warn(
#     417             "No tables found on {}".format(os.path.basename(self.rootname))
#     418         )
#     419     return []
# --> 421 self.backend.convert(self.filename, self.imagename)
#     423 self._generate_table_bbox()
#     425 _tables = []
#
# File c:\Python312\Lib\site-packages\camelot\backends\ghostscript_backend.py:31, in GhostscriptBackend.convert(self, pdf_path, png_path, resolution)
#      29 def convert(self, pdf_path, png_path, resolution=300):
#      30     if not self.installed():
# ---> 31         raise OSError(
#      32             "Ghostscript is not installed. You can install it using the instructions"
#      33             " here: https://camelot-py.readthedocs.io/en/master/user/install-deps.html"
#      34         )
#      36     import ghostscript
#      38     gs_command = [
#      39         "gs",
#      40         "-q",
#    (...)
#      45         pdf_path,
#      46     ]
#
# OSError: Ghostscript is not installed. You can install it using the instructions here: https://camelot-py.readthedocs.io/en/master/user/install-deps.html

# %%
tables1 = camelot.read_pdf("./tmp/pdf/MGI_Disruptive_technologies_Full_report_May2013.pdf", pages='32', area=[269.875, 120.75, 790.5, 561])
print (tabulate(tables1[0].df))

# %%
for i in range(30,35):
    print (i)
    tables = camelot.read_pdf("./tmp/pdf/MGI_Disruptive_technologies_Full_report_May2013.pdf", pages='%d' %  i)
    try:
        print (tabulate(tables[0].df))
        print (tabulate(tables[1].df))
    except IndexError:
        print('NOK')

# %% [markdown]
# ## Extract by PyPDF2
#
# #### Installation
#
# https://pypi.org/project/PyPDF2/
#
# `pip install PyPDF2`

# %%
import PyPDF2

pdf_file = open('mse.pdf', 'rb')
read_pdf = PyPDF2.PdfReader(pdf_file)
number_of_pages = len(read_pdf.pages) 
page = read_pdf.pages[2]
page_content = page.extract_text()
print(page_content)
# Out:
# 2-3
# Extc
# TE
# HMI
# (OE)
# CSE-DS
# TE
# HMI
# (PE)
# CSE-AIML
# TE
# HMI
# (PE)
# CE
# TE
# HMI
# (PE)
# IT/COMP
# BE
# HMI
# (PE)
# M.Tech
# extc
# Program
# Elective-II
# M.Tech
# comp
# Program
# Elective-II
# 3.30-4.30
# ALL
# DIVISONS
# FE
# ELECTIVES
# 4
# 7th
# March
# 2024
# 10-11
# Extc
# SE
# Signals
# and
# Systems
# CSE
# SE
# Computer
# Communications
# and
# Networks
# CE
# SE
# Computer
# Communications
# and
# Networks
# FYMCA
# FY
# Process
# Automation
# 11.30-12.30
# Extc
# TE
# SAP/DCMOS
# Etrx/EXTC
# BE
# SAP/DCMOS
# CSE-DS
# TE
# BA
# WITH
# PYTHON
# IT/COMP
# BE
# BA
# WITH
# PYTHON
# CSE-AIML
# TE
# BA
# WITH
# PYTHON
# CE
# TE
# BA
# WITH
# PYTHON
# 2-3
# Extc
# TE
# OE
# (except
# HMI
# and
# BCT)
# CSE-DS
# TE
# OE
# (except
# HMI
# and
# BCT)
# CSE-AIML
# TE
# OE
# (except
# HMI
# and
# BCT)
# CE
# TE
# OE
# (except
# HMI
# and
# BCT)
# M.Tech
# extc
# Program
# Elective-III
# M.Tech
# comp
# Program
# Elective-III
# 3.30-
# 5
# pm
# ABCD
# FE
# Soft
# skills
# 5.
# 11th
# march
# 2024
# 2-3
# FYMCA
# FY
# Program
# elective
# CSE-DS
# TE
# BDA
# IT/COMP
# BE
# BDA

# %%
import numpy

table_list = page_content.split('\n')
l = numpy.array_split(table_list, len(table_list)/4)
for i in range(0,5):
    print(l[i])
# Out:
# ['2-3' 'Extc' 'TE' 'HMI' '(OE)']
# ['CSE-DS' 'TE' 'HMI' '(PE)' 'CSE-AIML']
# ['TE' 'HMI' '(PE)' 'CE']
# ['TE' 'HMI' '(PE)' 'IT/COMP']
# ['BE' 'HMI' '(PE)' 'M.Tech']
